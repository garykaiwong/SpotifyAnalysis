# %%
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db = client.songsDB

# %%
import json

f = open('data.json')
tunes = json.load(f)

# %%
db.songs.insert_one(tunes)

# %%
songs_pull= db.songs.find()

# %%
songs_pull[0]['data']
# Out:
# [{'id': '1923',
#   'songs': ["Nobody Knows You When You're Down and Out",
#    'Weather Bird',
#    "'Tain't Nobody's Bizness If I Do",
#    "Ain't Misbehavin'",
#    'Empty Bed Blues, Pt. 1',
#    'Need a Little Sugar in My Bowl',
#    "Send Me to the 'Lectric Chair",
#    'Careless Love',
#    "Young Woman's Blues",
#    'Me and My Gin'],
#   'artists': ["['Bessie Smith']",
#    "['Louis Armstrong', 'Earl Hines']",
#    "['Bessie Smith']",
#    "['Louis Armstrong']",
#    "['Bessie Smith']",
#    "['Bessie Smith']",
#    "['Bessie Smith']",
#    "['Bessie Smith']",
#    "['Bessie Smith']",
#    "['Bessie Smith']"]},
#  {'id': '1924',
#   'songs': ["After You've Gone",
#    "Baby, Won't You Please Come Home",
#    'St. Louis Blues',
#    "Aggravatin' Papa",
#    'Down Hearted Blues',
#    'A Good Man Is Hard To Find',
#    "Alexander's Ragtime Band",
#    'In My Merry Oldsmobile',
#    'Mississippi Mud (feat. Bix Beiderbecke)',
#    'Summertime'],
# ...
